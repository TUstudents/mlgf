# %% [markdown]
# ### Generate labeled DFT and $GW$ Data
# should generate three chkfiles in the `./test_chk` directory. This step is the slow step (i.e. labeling the data with the $GW$ calculations that we want to accelerate with ML). You may skip this step and use the existing chkfiles in the test_chk folder
#
# arguments:
# 1. --xc pbe0 : DFT functional is PBE0
# 2. --gf gw : do a DFT+GW calculation and save everything to disk
# 3. --src : folder with .xyz files to use as structures for DFT
# 4. -o : folder where to write .chk files with all the calculation outputs
# 5. -b ccpvdz : use the ccpvdz basis
# 6. --gw_nw2 30 : evaluate sigmaI and gHF on 30 GL points (numerical integration within GWGF is still on full 100 GL points)

# %%
# !python -m mlgf.workflow.generate_splitxyz --xc pbe0 --gf gw --src ./test_xyz -o ./test_chk -b ccpvdz --gw_nw2 30

# %% [markdown]
# ### Inspect a chkfile by loading with Moldatum.load_chk()
# Here is a summary of the attributes in the Moldatum object:
# 1. `dm_gw` - $GW$-level correlated density matrix, MO basis
# 2. `dm_hf` - mean-field (DFT or Hartree-Fock) density matrix, AO basis
# 3. `e_tot` - DFT total energy
# 4. `ef` - DFT fermi level
# 5.  `fock` - DFT fock matrix, AO basis
# 6.  `freqs` - iomega points on which sigmaI (i.e. self-energy) is evaluated, typically not used, instead omega_fit is used
# 7.   `hcore` - DFT core hamiltonian, AO basis
# 8.   `mo_coeff` - DFT MO coefficients
# 9.   `mo_energy` - DFT KS orbital energies
# 10.   `mo_occ` - DFT MO occupation numbers
# 11.   `nocc` - number of occupied MOs
# 12.   `omega_ac` - subset of `omega_fit` used for AC fitting to obtain spectrum and QP energies
# 13.   `omega_fit` - full set `ef` + i*`freqs` points on which self-energy is evaluated. used for density matrix integration
# 14.   `ovlp` - overlap matrix S, AO basis
# 15.   `sigmaI` - self-energy on evaluated on imaginary frequencies, MO basis
# 16.   `time_gw`, `time_rks` - calculation times for $GW$ and $DFT$
# 17.   `vj` - DFT coulomb matrix J, AO basis
# 18.   `vk` - DFT exchange matrix K, AO basis
# 19.   `vk_hf` - $V_text{xc} - V_k$  (equal $V_k / 2$ for Hartree-Fock calculation)
# 20.   `vxc` - $V_text{xc}$ from DFT
# 21.   `wts` - Gauss-Legendre weights for density-matrix integration
# 22.   `xc` - the type of DFT exchange
# 23.   `inds_core` - the AO/SAIAO indices corresponding to core orbitals
# 24.   `C_ao_saiao` - rotation AO to SAIAO
# 25.   `my_feature_saiao` - features above in the SAIAO equivariant basis
# 26.   `fname` - chkfile name that was read to create the Moldatum object

# %%
from mlgf.data import Moldatum
import os

current_dir = os.getcwd()
chkfile_src_dir = f'{current_dir}/test_chk'

my_chkfile = f'{chkfile_src_dir}/methane.chk'
my_mlf = Moldatum.load_chk(my_chkfile)
print(my_mlf.keys())

# Note that there are some additional feature matrices compared to the raw chkfile loaded without Moldatum.load_chk() because we call get_saiao_features inside Moldatum.load_chk()
# Out:
# dict_keys(['coeff', 'dm_gw', 'dm_hf', 'e_tot', 'ef', 'fock', 'freqs', 'hcore', 'mo_coeff', 'mo_energy', 'mo_occ', 'mol', 'nocc', 'omega_ac', 'omega_fit', 'ovlp', 'sigmaI', 'time_gw', 'time_rks', 'vj', 'vk', 'vk_hf', 'vxc', 'wts', 'xc', 'inds_core', 'C_ao_saiao', 'sigma_saiao', 'dm_saiao', 'fock_saiao', 'hcore_saiao', 'vj_saiao', 'vk_saiao', 'C_saiao_mo', 'vxc_saiao', 'cat_orbtype_principal', 'cat_orbtype_angular', 'cat_orbtype_saiao', 'fock_iao', 'C_ao_iao', 'C_iao_saiao', 'hcore+vj_saiao', 'atomic_charge_saiao', 'boys_saiao', 'fname'])

# %%
# we cam also load the file as a mol and scf with pyscf.lib
from pyscf import lib
my_chkfile = f'{chkfile_src_dir}/methane.chk'
my_scf_data = lib.chkfile.load(my_chkfile, 'scf')
my_mol = lib.chkfile.load_mol(my_chkfile)
print(my_mol)
print(my_scf_data)

# %% [markdown]
# ### Read and modify MBGF-Net metadata
# This code chunk will edit file paths involved in the MBGF-Net workflow. It first loads metadata in 'gnn_config.json'm then modifies path variables to point to your working directory. Finally overwrites overwrites with new file paths for the next two steps

# %%
import json
import os

json_file = 'gnn_config.json'


with open(json_file) as f:
    job = json.load(f)


current_dir = os.getcwd()
chkfile_src_dir = f'{current_dir}/test_chk'

# training data: methane, ammonia, water (not ethane, this is the test case)
my_train_files = [f'{chkfile_src_dir}/methane.chk', f'{chkfile_src_dir}/water.chk', f'{chkfile_src_dir}/ammonia.chk']

my_test_joblib_file = f'{current_dir}/test_gnn_orchestrator.joblib' # pic
torch_data_root = f'{current_dir}/torch_data_root' # where the graph objects are written to
dset_store_dir = f'{current_dir}/dset_tmp_dir' # temporary directory, deleted after prepare_gnn_data.py

job['train_files'] = my_train_files
job['gnn_orch_file_to_copy'] = my_test_joblib_file
job['gnn_orch_file'] = my_test_joblib_file
job['torch_data_root'] = torch_data_root
job['dset_store_dir'] = dset_store_dir


with open(json_file, 'w') as f:
    json.dump(job, f, indent=4)

# %% [markdown]
# ### Create the `GraphOrchestrator` class with mlgf.model.prepare_gnn_data and save to joblib
# The above metadata specification dictates the creation of the `GraphOrchestrator` class, which controls many aspects of the GNN workflow, including:
# 1. Sourcing DFT and $GW$ calculations saved .chk file (numpy h5 format) as the training data
# 2. Transformation/standardization of DFT features $X_{ii}$ and $X_{ij}$
# 3. Converting DFT and $GW$ data for each system into a custom graph object that inherits from `torch_geometric.data.Data` object. Each graph object holds node features, edge features, node-pair indices for each edge, SAIAO to MO rotation matrices, MO energies, number of occupied orbitals, and indices that map graph attributes (which may have edges and nodes removed) to full self-energy indicies (full nmo x nmo x nomega)
# 4. `torch_geometric.data.Dataset` object that holds indexable Graph objects from file reads
# 5. Storing training hyperparameters for the loss function (`loss_kwargs`) and the MBGF-Net architecture (`model_kwargs`)
# 6. Predicting the full self-energy of an unseen DFT calculation from .chk file with MBGF-Net
#
# Starting from a list of chkfiles with DFT and $GW$ data, the intended workflow relies on a metadata config read as .json:
# 1. Call mlgf.model.prepare_gnn_data to prepare the graph objects for training the self-energy GNN
# 2. Call mlgf.model.train_graph_ensemble to train the GNN with `model_kwargs`, `loss_kwargs`, and `train_config`

# %%
# !python -m mlgf.model.prepare_gnn_data --json_spec gnn_config.json
# Out:
# /root/capsule/code/fcdmft/fcdmft/gw/mol/gw_ac.py:52: UserWarning: PES fitting is not available: No module named 'fcdmft.gw.mol.pes'
#   warnings.warn(f"PES fitting is not available: {e}")
# /root/capsule/code/mlgf/mlgf/lib/pes.py:10: UserWarning: PES fitting is not available: No module named 'cvxpy'
#   warnings.warn(f"PES fitting is not available: {e}")
# None
# gnn_orch_file:  /root/capsule/code/mlgf/examples/test_gnn_orchestrator.joblib
# dset_store_dir:  /root/capsule/code/mlgf/examples/dset_tmp_dir
# torch_data_root:  /root/capsule/code/mlgf/examples/torch_data_root
# -----Checking integrity of data on rank 0-----
# Aug 19 14:34:53 #######
#                 ####### libDMET   version 0.5
#                 ####### A periodic DMET library for lattice model and realistic solid.
#                 #######
# /root/capsule/code/mlgf/mlgf/model/gnn_orchestrator.py:582: UserWarning: The supplied torch_data_root exists, removing existing tree!
#   warnings.warn(f'The supplied torch_data_root exists, removing existing tree!')

# %% [markdown]
# #### Inspect The `GraphOrchestrator` object before training the GNN
# Load with joblib and inspect its GraphDataset object, which contains Graphs that can be indexed like elements of a list.

# %%
import joblib
gnn_orch = joblib.load('test_gnn_orchestrator.joblib') # controls most of the data processing workflow
print(gnn_orch.data) # GraphDataset object is the data attribute (essentially a list of Graph objects)
print(gnn_orch.data[0]) # GraphDataset can be indexed like list to get all the Graph objects
# Out:
# GraphDataset(3)
# Graph(x=[33, 46], edge_index=[2, 854], edge_attr=[854, 60], nodes_plus_edges=887, nmo=34, mo_energy=[34], node_indices_nonzero=[33], edge_indices_nonzero=[854, 2], undirected=True, fname='/root/capsule/code/mlgf/examples/test_chk/methane.chk', ef=-0.1548177835534029, nomega=30, iomega=[30], num_elements_inv=[1], n_edges=854, n_nodes=33, homo_ind=4, lumo_ind=5, C_lo_mo=[1156], sigma_ii=[33, 60], sigma_ij=[854, 60])
# /root/capsule/code/mlgf/mlgf/lib/pes.py:10: UserWarning: PES fitting is not available: No module named 'cvxpy'
#   warnings.warn(f"PES fitting is not available: {e}")

# %% [markdown]
# ### Train MBGF-Net
# Key json config variables:
# 1. train_config: the parameters for Adam gradient descent: batch_size, epochs, learning_rate, learning_rate schedule
# 2. model_kwargs: parameters controlling sizes of GNN modules (scale_y = 0.001 means we train self-energy in units of mH)
# 3. loss_kwargs: loss parameters

# %%
# !python -m mlgf.model.train_graph_ensemble --json_spec gnn_config.json
# Out:
# /root/capsule/code/fcdmft/fcdmft/gw/mol/gw_ac.py:52: UserWarning: PES fitting is not available: No module named 'fcdmft.gw.mol.pes'
#   warnings.warn(f"PES fitting is not available: {e}")
# /root/capsule/code/mlgf/mlgf/lib/pes.py:10: UserWarning: PES fitting is not available: No module named 'cvxpy'
#   warnings.warn(f"PES fitting is not available: {e}")
# gnn_orch_file: /root/capsule/code/mlgf/examples/test_gnn_orchestrator.joblib
# train_config:  {'epochs': 400, 'learning_rate': 0.001, 'weight_decay': 0.0, 'optimizer': 'Adam', 'dropout': 0.0, 'batch_size': 1, 'shuffle': True, 'num_workers': 0, 'cosine_t0': 100, 'cos_range': [100, 300]}
# loss_kwargs:  {'frontier_weight': 0.1, 'smoothness_weight': 0.0, 'gradient_weight': 0.1, 'frontier_range': [10, 10], 'always_in_batch': []}
# Device used for training:  cpu
# Model total number of params:  667212
# tensor([7.7784e-04, 4.1166e-03, 1.0198e-02, 1.9157e-02, 3.1191e-02, 4.6578e-02,
#         6.5682e-02, 8.8980e-02, 1.1708e-01, 1.5078e-01, 1.9107e-01, 2.3926e-01,
#         2.9704e-01, 3.6665e-01, 4.5105e-01, 5.5426e-01, 6.8185e-01, 8.4163e-01,
#         1.0449e+00, 1.3084e+00, 1.6581e+00, 2.1352e+00, 2.8096e+00, 3.8062e+00,
#         5.3674e+00, 8.0150e+00, 1.3050e+01, 2.4514e+01, 6.0730e+01, 3.2140e+02],
#        dtype=torch.float64)
# -------Loss function initialization of precision and device-------
# attr x_values put on device: cpu
# attr x1_d2 put on device: cpu
# attr x2_d2 put on device: cpu
# attr x3_d2 put on device: cpu
# attr x_d1 put on device: cpu
# -------End Loss function initialization-------
# training_scale: 0.001
# time for Adam #0: 0.12s, main loop value (final batch loss): 6.032922e+01, step_size: 1.000000e-03
# time for Adam #1: 0.09s, main loop value (final batch loss): 6.010596e+01, step_size: 1.000000e-03
# time for Adam #2: 0.09s, main loop value (final batch loss): 8.334605e+01, step_size: 1.000000e-03
# time for Adam #3: 0.09s, main loop value (final batch loss): 7.034633e+01, step_size: 1.000000e-03
# time for Adam #4: 0.09s, main loop value (final batch loss): 8.153456e+01, step_size: 1.000000e-03
# time for Adam #5: 0.09s, main loop value (final batch loss): 7.950218e+01, step_size: 1.000000e-03
# time for Adam #6: 0.09s, main loop value (final batch loss): 7.564671e+01, step_size: 1.000000e-03
# time for Adam #7: 0.09s, main loop value (final batch loss): 6.762175e+01, step_size: 1.000000e-03
# time for Adam #8: 0.09s, main loop value (final batch loss): 3.258410e+01, step_size: 1.000000e-03
# time for Adam #9: 0.09s, main loop value (final batch loss): 1.948891e+01, step_size: 1.000000e-03
# time for Adam #10: 0.09s, main loop value (final batch loss): 1.382433e+01, step_size: 1.000000e-03
# time for Adam #11: 0.10s, main loop value (final batch loss): 1.337116e+01, step_size: 1.000000e-03
# time for Adam #12: 0.09s, main loop value (final batch loss): 2.764221e+01, step_size: 1.000000e-03
# time for Adam #13: 0.09s, main loop value (final batch loss): 1.215333e+01, step_size: 1.000000e-03
# time for Adam #14: 0.09s, main loop value (final batch loss): 1.227774e+01, step_size: 1.000000e-03
# time for Adam #15: 0.09s, main loop value (final batch loss): 1.047324e+01, step_size: 1.000000e-03
# time for Adam #16: 0.09s, main loop value (final batch loss): 7.419119e+00, step_size: 1.000000e-03
# time for Adam #17: 0.09s, main loop value (final batch loss): 9.309381e+00, step_size: 1.000000e-03
# time for Adam #18: 0.09s, main loop value (final batch loss): 8.597421e+00, step_size: 1.000000e-03
# time for Adam #19: 0.09s, main loop value (final batch loss): 1.983005e+01, step_size: 1.000000e-03
# time for Adam #20: 0.09s, main loop value (final batch loss): 6.915749e+00, step_size: 1.000000e-03
# time for Adam #21: 0.09s, main loop value (final batch loss): 6.618184e+00, step_size: 1.000000e-03
# time for Adam #22: 0.09s, main loop value (final batch loss): 5.829651e+00, step_size: 1.000000e-03
# time for Adam #23: 0.10s, main loop value (final batch loss): 1.739409e+01, step_size: 1.000000e-03
# time for Adam #24: 0.09s, main loop value (final batch loss): 4.423753e+00, step_size: 1.000000e-03
# time for Adam #25: 0.10s, main loop value (final batch loss): 1.549996e+01, step_size: 1.000000e-03
# time for Adam #26: 0.10s, main loop value (final batch loss): 3.971306e+00, step_size: 1.000000e-03
# time for Adam #27: 0.10s, main loop value (final batch loss): 1.343468e+01, step_size: 1.000000e-03
# time for Adam #28: 0.10s, main loop value (final batch loss): 1.295885e+01, step_size: 1.000000e-03
# time for Adam #29: 0.10s, main loop value (final batch loss): 1.262330e+01, step_size: 1.000000e-03
# time for Adam #30: 0.09s, main loop value (final batch loss): 1.210093e+01, step_size: 1.000000e-03
# time for Adam #31: 0.10s, main loop value (final batch loss): 5.393916e+00, step_size: 1.000000e-03
# time for Adam #32: 0.09s, main loop value (final batch loss): 3.225525e+00, step_size: 1.000000e-03
# time for Adam #33: 0.09s, main loop value (final batch loss): 5.032667e+00, step_size: 1.000000e-03
# time for Adam #34: 0.09s, main loop value (final batch loss): 4.841887e+00, step_size: 1.000000e-03
# time for Adam #35: 0.09s, main loop value (final batch loss): 4.811634e+00, step_size: 1.000000e-03
# time for Adam #36: 0.09s, main loop value (final batch loss): 4.592098e+00, step_size: 1.000000e-03
# time for Adam #37: 0.10s, main loop value (final batch loss): 2.687031e+00, step_size: 1.000000e-03
# time for Adam #38: 0.09s, main loop value (final batch loss): 8.795758e+00, step_size: 1.000000e-03
# time for Adam #39: 0.09s, main loop value (final batch loss): 8.545591e+00, step_size: 1.000000e-03
# time for Adam #40: 0.09s, main loop value (final batch loss): 8.147182e+00, step_size: 1.000000e-03
# time for Adam #41: 0.09s, main loop value (final batch loss): 8.045172e+00, step_size: 1.000000e-03
# time for Adam #42: 0.09s, main loop value (final batch loss): 3.922228e+00, step_size: 1.000000e-03
# time for Adam #43: 0.10s, main loop value (final batch loss): 2.202671e+00, step_size: 1.000000e-03
# time for Adam #44: 0.09s, main loop value (final batch loss): 3.756700e+00, step_size: 1.000000e-03
# time for Adam #45: 0.09s, main loop value (final batch loss): 3.689744e+00, step_size: 1.000000e-03
# time for Adam #46: 0.10s, main loop value (final batch loss): 3.603439e+00, step_size: 1.000000e-03
# time for Adam #47: 0.09s, main loop value (final batch loss): 3.494640e+00, step_size: 1.000000e-03
# time for Adam #48: 0.09s, main loop value (final batch loss): 1.954860e+00, step_size: 1.000000e-03
# time for Adam #49: 0.09s, main loop value (final batch loss): 5.953054e+00, step_size: 1.000000e-03
# time for Adam #50: 0.10s, main loop value (final batch loss): 5.810585e+00, step_size: 1.000000e-03
# time for Adam #51: 0.09s, main loop value (final batch loss): 5.624478e+00, step_size: 1.000000e-03
# time for Adam #52: 0.09s, main loop value (final batch loss): 5.327165e+00, step_size: 1.000000e-03
# time for Adam #53: 0.10s, main loop value (final batch loss): 1.744141e+00, step_size: 1.000000e-03
# time for Adam #54: 0.10s, main loop value (final batch loss): 3.074054e+00, step_size: 1.000000e-03
# time for Adam #55: 0.09s, main loop value (final batch loss): 1.742390e+00, step_size: 1.000000e-03
# time for Adam #56: 0.09s, main loop value (final batch loss): 4.707058e+00, step_size: 1.000000e-03
# time for Adam #57: 0.09s, main loop value (final batch loss): 4.694672e+00, step_size: 1.000000e-03
# time for Adam #58: 0.09s, main loop value (final batch loss): 2.078808e+00, step_size: 1.000000e-03
# time for Adam #59: 0.09s, main loop value (final batch loss): 1.828742e+00, step_size: 1.000000e-03
# time for Adam #60: 0.09s, main loop value (final batch loss): 4.328855e+00, step_size: 1.000000e-03
# time for Adam #61: 0.09s, main loop value (final batch loss): 3.310009e+00, step_size: 1.000000e-03
# time for Adam #62: 0.09s, main loop value (final batch loss): 3.135428e+00, step_size: 1.000000e-03
# time for Adam #63: 0.09s, main loop value (final batch loss): 5.395419e+00, step_size: 1.000000e-03
# time for Adam #64: 0.09s, main loop value (final batch loss): 2.710988e+00, step_size: 1.000000e-03
# time for Adam #65: 0.09s, main loop value (final batch loss): 2.437628e+00, step_size: 1.000000e-03
# time for Adam #66: 0.09s, main loop value (final batch loss): 1.931284e+00, step_size: 1.000000e-03
# time for Adam #67: 0.10s, main loop value (final batch loss): 1.510808e+00, step_size: 1.000000e-03
# time for Adam #68: 0.09s, main loop value (final batch loss): 2.308365e+00, step_size: 1.000000e-03
# time for Adam #69: 0.09s, main loop value (final batch loss): 1.364740e+00, step_size: 1.000000e-03
# time for Adam #70: 0.09s, main loop value (final batch loss): 3.386496e+00, step_size: 1.000000e-03
# time for Adam #71: 0.09s, main loop value (final batch loss): 2.170771e+00, step_size: 1.000000e-03
# time for Adam #72: 0.09s, main loop value (final batch loss): 2.076168e+00, step_size: 1.000000e-03
# time for Adam #73: 0.09s, main loop value (final batch loss): 2.043852e+00, step_size: 1.000000e-03
# time for Adam #74: 0.09s, main loop value (final batch loss): 1.184565e+00, step_size: 1.000000e-03
# time for Adam #75: 0.09s, main loop value (final batch loss): 2.932502e+00, step_size: 1.000000e-03
# time for Adam #76: 0.10s, main loop value (final batch loss): 2.825708e+00, step_size: 1.000000e-03
# time for Adam #77: 0.09s, main loop value (final batch loss): 1.927484e+00, step_size: 1.000000e-03
# time for Adam #78: 0.10s, main loop value (final batch loss): 1.107537e+00, step_size: 1.000000e-03
# time for Adam #79: 0.09s, main loop value (final batch loss): 2.621752e+00, step_size: 1.000000e-03
# time for Adam #80: 0.10s, main loop value (final batch loss): 1.065932e+00, step_size: 1.000000e-03
# time for Adam #81: 0.09s, main loop value (final batch loss): 1.745334e+00, step_size: 1.000000e-03
# time for Adam #82: 0.09s, main loop value (final batch loss): 2.357941e+00, step_size: 1.000000e-03
# time for Adam #83: 0.10s, main loop value (final batch loss): 2.316090e+00, step_size: 1.000000e-03
# time for Adam #84: 0.09s, main loop value (final batch loss): 1.597000e+00, step_size: 1.000000e-03
# time for Adam #85: 0.09s, main loop value (final batch loss): 2.153906e+00, step_size: 1.000000e-03
# time for Adam #86: 0.10s, main loop value (final batch loss): 2.107964e+00, step_size: 1.000000e-03
# time for Adam #87: 0.09s, main loop value (final batch loss): 1.505568e+00, step_size: 1.000000e-03
# time for Adam #88: 0.10s, main loop value (final batch loss): 2.141787e+00, step_size: 1.000000e-03
# time for Adam #89: 0.09s, main loop value (final batch loss): 1.660331e+00, step_size: 1.000000e-03
# time for Adam #90: 0.09s, main loop value (final batch loss): 1.421833e+00, step_size: 1.000000e-03
# time for Adam #91: 0.09s, main loop value (final batch loss): 1.199108e+00, step_size: 1.000000e-03
# time for Adam #92: 0.09s, main loop value (final batch loss): 3.530115e+00, step_size: 1.000000e-03
# time for Adam #93: 0.09s, main loop value (final batch loss): 1.945790e+00, step_size: 1.000000e-03
# time for Adam #94: 0.09s, main loop value (final batch loss): 2.421547e+00, step_size: 1.000000e-03
# time for Adam #95: 0.09s, main loop value (final batch loss): 9.115067e-01, step_size: 1.000000e-03
# time for Adam #96: 0.09s, main loop value (final batch loss): 1.898452e+00, step_size: 1.000000e-03
# time for Adam #97: 0.10s, main loop value (final batch loss): 1.729934e+00, step_size: 1.000000e-03
# time for Adam #98: 0.09s, main loop value (final batch loss): 9.490583e-01, step_size: 1.000000e-03
# time for Adam #99: 0.10s, main loop value (final batch loss): 2.015699e+00, step_size: 1.000000e-03
# time for Adam #100: 0.09s, main loop value (final batch loss): 1.124822e+00, step_size: 1.000000e-03
# time for Adam #101: 0.09s, main loop value (final batch loss): 1.800963e+00, step_size: 9.997533e-04
# time for Adam #102: 0.10s, main loop value (final batch loss): 1.235866e+00, step_size: 9.990134e-04
# time for Adam #103: 0.09s, main loop value (final batch loss): 7.110871e-01, step_size: 9.977810e-04
# time for Adam #104: 0.09s, main loop value (final batch loss): 6.797335e-01, step_size: 9.960574e-04
# time for Adam #105: 0.09s, main loop value (final batch loss): 1.565602e+00, step_size: 9.938442e-04
# time for Adam #106: 0.10s, main loop value (final batch loss): 1.061566e+00, step_size: 9.911436e-04
# time for Adam #107: 0.09s, main loop value (final batch loss): 7.201043e-01, step_size: 9.879584e-04
# time for Adam #108: 0.09s, main loop value (final batch loss): 1.152038e+00, step_size: 9.842916e-04
# time for Adam #109: 0.09s, main loop value (final batch loss): 1.000948e+00, step_size: 9.801468e-04
# time for Adam #110: 0.09s, main loop value (final batch loss): 1.322489e+00, step_size: 9.755283e-04
# time for Adam #111: 0.09s, main loop value (final batch loss): 8.002442e-01, step_size: 9.704404e-04
# time for Adam #112: 0.09s, main loop value (final batch loss): 1.286402e+00, step_size: 9.648882e-04
# time for Adam #113: 0.09s, main loop value (final batch loss): 5.660657e-01, step_size: 9.588773e-04
# time for Adam #114: 0.09s, main loop value (final batch loss): 9.767372e-01, step_size: 9.524135e-04
# time for Adam #115: 0.10s, main loop value (final batch loss): 1.064812e+00, step_size: 9.455033e-04
# time for Adam #116: 0.10s, main loop value (final batch loss): 1.042507e+00, step_size: 9.381533e-04
# time for Adam #117: 0.09s, main loop value (final batch loss): 1.077723e+00, step_size: 9.303710e-04
# time for Adam #118: 0.09s, main loop value (final batch loss): 9.673193e-01, step_size: 9.221640e-04
# time for Adam #119: 0.09s, main loop value (final batch loss): 9.005603e-01, step_size: 9.135403e-04
# time for Adam #120: 0.09s, main loop value (final batch loss): 9.007799e-01, step_size: 9.045085e-04
# time for Adam #121: 0.09s, main loop value (final batch loss): 8.620467e-01, step_size: 8.950775e-04
# time for Adam #122: 0.09s, main loop value (final batch loss): 8.967856e-01, step_size: 8.852566e-04
# time for Adam #123: 0.09s, main loop value (final batch loss): 8.661641e-01, step_size: 8.750555e-04
# time for Adam #124: 0.09s, main loop value (final batch loss): 8.727746e-01, step_size: 8.644843e-04
# time for Adam #125: 0.09s, main loop value (final batch loss): 4.747633e-01, step_size: 8.535534e-04
# time for Adam #126: 0.09s, main loop value (final batch loss): 6.792582e-01, step_size: 8.422736e-04
# time for Adam #127: 0.09s, main loop value (final batch loss): 7.554064e-01, step_size: 8.306559e-04
# time for Adam #128: 0.09s, main loop value (final batch loss): 6.461945e-01, step_size: 8.187120e-04
# time for Adam #129: 0.10s, main loop value (final batch loss): 6.256737e-01, step_size: 8.064535e-04
# time for Adam #130: 0.09s, main loop value (final batch loss): 4.047822e-01, step_size: 7.938926e-04
# time for Adam #131: 0.09s, main loop value (final batch loss): 4.219000e-01, step_size: 7.810417e-04
# time for Adam #132: 0.10s, main loop value (final batch loss): 4.014294e-01, step_size: 7.679134e-04
# time for Adam #133: 0.09s, main loop value (final batch loss): 6.606603e-01, step_size: 7.545207e-04
# time for Adam #134: 0.09s, main loop value (final batch loss): 5.717049e-01, step_size: 7.408768e-04
# time for Adam #135: 0.09s, main loop value (final batch loss): 6.208744e-01, step_size: 7.269952e-04
# time for Adam #136: 0.09s, main loop value (final batch loss): 6.075853e-01, step_size: 7.128896e-04
# time for Adam #137: 0.09s, main loop value (final batch loss): 5.925119e-01, step_size: 6.985739e-04
# time for Adam #138: 0.09s, main loop value (final batch loss): 5.747162e-01, step_size: 6.840623e-04
# time for Adam #139: 0.09s, main loop value (final batch loss): 3.617020e-01, step_size: 6.693690e-04
# time for Adam #140: 0.10s, main loop value (final batch loss): 5.195860e-01, step_size: 6.545085e-04
# time for Adam #141: 0.09s, main loop value (final batch loss): 5.436696e-01, step_size: 6.394956e-04
# time for Adam #142: 0.09s, main loop value (final batch loss): 3.659942e-01, step_size: 6.243449e-04
# time for Adam #143: 0.09s, main loop value (final batch loss): 4.902855e-01, step_size: 6.090716e-04
# time for Adam #144: 0.09s, main loop value (final batch loss): 3.460126e-01, step_size: 5.936907e-04
# time for Adam #145: 0.09s, main loop value (final batch loss): 4.746478e-01, step_size: 5.782172e-04
# time for Adam #146: 0.09s, main loop value (final batch loss): 4.683541e-01, step_size: 5.626666e-04
# time for Adam #147: 0.09s, main loop value (final batch loss): 3.308261e-01, step_size: 5.470542e-04
# time for Adam #148: 0.09s, main loop value (final batch loss): 3.278394e-01, step_size: 5.313953e-04
# time for Adam #149: 0.09s, main loop value (final batch loss): 4.618000e-01, step_size: 5.157054e-04
# time for Adam #150: 0.10s, main loop value (final batch loss): 4.530957e-01, step_size: 5.000000e-04
# time for Adam #151: 0.09s, main loop value (final batch loss): 4.453891e-01, step_size: 4.842946e-04
# time for Adam #152: 0.09s, main loop value (final batch loss): 3.209853e-01, step_size: 4.686047e-04
# time for Adam #153: 0.09s, main loop value (final batch loss): 3.180005e-01, step_size: 4.529458e-04
# time for Adam #154: 0.09s, main loop value (final batch loss): 3.162759e-01, step_size: 4.373334e-04
# time for Adam #155: 0.09s, main loop value (final batch loss): 4.201361e-01, step_size: 4.217828e-04
# time for Adam #156: 0.09s, main loop value (final batch loss): 4.161770e-01, step_size: 4.063093e-04
# time for Adam #157: 0.09s, main loop value (final batch loss): 3.080525e-01, step_size: 3.909284e-04
# time for Adam #158: 0.09s, main loop value (final batch loss): 3.077980e-01, step_size: 3.756551e-04
# time for Adam #159: 0.09s, main loop value (final batch loss): 4.158281e-01, step_size: 3.605044e-04
# time for Adam #160: 0.09s, main loop value (final batch loss): 4.113429e-01, step_size: 3.454915e-04
# time for Adam #161: 0.10s, main loop value (final batch loss): 3.894215e-01, step_size: 3.306310e-04
# time for Adam #162: 0.09s, main loop value (final batch loss): 3.888494e-01, step_size: 3.159377e-04
# time for Adam #163: 0.09s, main loop value (final batch loss): 4.001903e-01, step_size: 3.014261e-04
# time for Adam #164: 0.09s, main loop value (final batch loss): 2.975967e-01, step_size: 2.871104e-04
# time for Adam #165: 0.09s, main loop value (final batch loss): 3.766892e-01, step_size: 2.730048e-04
# time for Adam #166: 0.09s, main loop value (final batch loss): 3.739628e-01, step_size: 2.591232e-04
# time for Adam #167: 0.09s, main loop value (final batch loss): 3.906563e-01, step_size: 2.454793e-04
# time for Adam #168: 0.09s, main loop value (final batch loss): 3.671278e-01, step_size: 2.320866e-04
# time for Adam #169: 0.09s, main loop value (final batch loss): 3.637986e-01, step_size: 2.189583e-04
# time for Adam #170: 0.09s, main loop value (final batch loss): 3.880708e-01, step_size: 2.061074e-04
# time for Adam #171: 0.09s, main loop value (final batch loss): 2.902652e-01, step_size: 1.935465e-04
# time for Adam #172: 0.10s, main loop value (final batch loss): 2.894294e-01, step_size: 1.812880e-04
# time for Adam #173: 0.09s, main loop value (final batch loss): 3.840396e-01, step_size: 1.693441e-04
# time for Adam #174: 0.09s, main loop value (final batch loss): 3.809290e-01, step_size: 1.577264e-04
# time for Adam #175: 0.09s, main loop value (final batch loss): 2.877801e-01, step_size: 1.464466e-04
# time for Adam #176: 0.09s, main loop value (final batch loss): 2.864067e-01, step_size: 1.355157e-04
# time for Adam #177: 0.10s, main loop value (final batch loss): 2.867281e-01, step_size: 1.249445e-04
# time for Adam #178: 0.10s, main loop value (final batch loss): 2.854667e-01, step_size: 1.147434e-04
# time for Adam #179: 0.10s, main loop value (final batch loss): 3.736947e-01, step_size: 1.049225e-04
# time for Adam #180: 0.09s, main loop value (final batch loss): 3.732963e-01, step_size: 9.549150e-05
# time for Adam #181: 0.09s, main loop value (final batch loss): 2.837257e-01, step_size: 8.645971e-05
# time for Adam #182: 0.09s, main loop value (final batch loss): 3.733417e-01, step_size: 7.783604e-05
# time for Adam #183: 0.09s, main loop value (final batch loss): 2.830531e-01, step_size: 6.962899e-05
# time for Adam #184: 0.09s, main loop value (final batch loss): 3.428283e-01, step_size: 6.184666e-05
# time for Adam #185: 0.09s, main loop value (final batch loss): 3.698584e-01, step_size: 5.449674e-05
# time for Adam #186: 0.09s, main loop value (final batch loss): 3.704039e-01, step_size: 4.758647e-05
# time for Adam #187: 0.09s, main loop value (final batch loss): 2.819697e-01, step_size: 4.112269e-05
# time for Adam #188: 0.09s, main loop value (final batch loss): 2.818244e-01, step_size: 3.511176e-05
# time for Adam #189: 0.09s, main loop value (final batch loss): 2.817388e-01, step_size: 2.955962e-05
# time for Adam #190: 0.09s, main loop value (final batch loss): 3.684981e-01, step_size: 2.447174e-05
# time for Adam #191: 0.09s, main loop value (final batch loss): 2.814328e-01, step_size: 1.985316e-05
# time for Adam #192: 0.10s, main loop value (final batch loss): 3.680823e-01, step_size: 1.570842e-05
# time for Adam #193: 0.09s, main loop value (final batch loss): 3.681480e-01, step_size: 1.204162e-05
# time for Adam #194: 0.09s, main loop value (final batch loss): 2.812291e-01, step_size: 8.856375e-06
# time for Adam #195: 0.09s, main loop value (final batch loss): 3.680477e-01, step_size: 6.155830e-06
# time for Adam #196: 0.09s, main loop value (final batch loss): 3.680172e-01, step_size: 3.942649e-06
# time for Adam #197: 0.09s, main loop value (final batch loss): 3.380816e-01, step_size: 2.219018e-06
# time for Adam #198: 0.09s, main loop value (final batch loss): 3.679531e-01, step_size: 9.866358e-07
# time for Adam #199: 0.09s, main loop value (final batch loss): 3.380639e-01, step_size: 2.467198e-07
# time for Adam #200: 0.09s, main loop value (final batch loss): 2.858561e-01, step_size: 1.000000e-03
# time for Adam #201: 0.09s, main loop value (final batch loss): 3.323169e-01, step_size: 9.997533e-04
# time for Adam #202: 0.09s, main loop value (final batch loss): 4.937513e-01, step_size: 9.990134e-04
# time for Adam #203: 0.10s, main loop value (final batch loss): 4.052291e-01, step_size: 9.977810e-04
# time for Adam #204: 0.09s, main loop value (final batch loss): 6.437398e-01, step_size: 9.960574e-04
# time for Adam #205: 0.09s, main loop value (final batch loss): 6.688114e-01, step_size: 9.938442e-04
# time for Adam #206: 0.09s, main loop value (final batch loss): 7.790247e-01, step_size: 9.911436e-04
# time for Adam #207: 0.09s, main loop value (final batch loss): 6.391079e-01, step_size: 9.879584e-04
# time for Adam #208: 0.09s, main loop value (final batch loss): 2.876263e+00, step_size: 9.842916e-04
# time for Adam #209: 0.09s, main loop value (final batch loss): 1.611484e+00, step_size: 9.801468e-04
# time for Adam #210: 0.09s, main loop value (final batch loss): 9.500448e-01, step_size: 9.755283e-04
# time for Adam #211: 0.09s, main loop value (final batch loss): 1.250315e+00, step_size: 9.704404e-04
# time for Adam #212: 0.09s, main loop value (final batch loss): 8.428158e-01, step_size: 9.648882e-04
# time for Adam #213: 0.09s, main loop value (final batch loss): 7.131573e-01, step_size: 9.588773e-04
# time for Adam #214: 0.09s, main loop value (final batch loss): 1.002187e+00, step_size: 9.524135e-04
# time for Adam #215: 0.09s, main loop value (final batch loss): 7.548279e-01, step_size: 9.455033e-04
# time for Adam #216: 0.09s, main loop value (final batch loss): 7.078150e-01, step_size: 9.381533e-04
# time for Adam #217: 0.09s, main loop value (final batch loss): 7.326920e-01, step_size: 9.303710e-04
# time for Adam #218: 0.09s, main loop value (final batch loss): 6.515621e-01, step_size: 9.221640e-04
# time for Adam #219: 0.09s, main loop value (final batch loss): 1.586370e+00, step_size: 9.135403e-04
# time for Adam #220: 0.09s, main loop value (final batch loss): 8.523204e-01, step_size: 9.045085e-04
# time for Adam #221: 0.10s, main loop value (final batch loss): 9.713827e-01, step_size: 8.950775e-04
# time for Adam #222: 0.09s, main loop value (final batch loss): 7.480592e-01, step_size: 8.852566e-04
# time for Adam #223: 0.09s, main loop value (final batch loss): 5.963632e-01, step_size: 8.750555e-04
# time for Adam #224: 0.10s, main loop value (final batch loss): 4.441523e-01, step_size: 8.644843e-04
# time for Adam #225: 0.09s, main loop value (final batch loss): 3.288950e-01, step_size: 8.535534e-04
# time for Adam #226: 0.09s, main loop value (final batch loss): 2.786241e-01, step_size: 8.422736e-04
# time for Adam #227: 0.09s, main loop value (final batch loss): 3.763952e-01, step_size: 8.306559e-04
# time for Adam #228: 0.09s, main loop value (final batch loss): 2.803475e-01, step_size: 8.187120e-04
# time for Adam #229: 0.09s, main loop value (final batch loss): 2.553818e-01, step_size: 8.064535e-04
# time for Adam #230: 0.09s, main loop value (final batch loss): 3.036653e-01, step_size: 7.938926e-04
# time for Adam #231: 0.09s, main loop value (final batch loss): 2.955916e-01, step_size: 7.810417e-04
# time for Adam #232: 0.09s, main loop value (final batch loss): 3.041283e-01, step_size: 7.679134e-04
# time for Adam #233: 0.09s, main loop value (final batch loss): 2.740042e-01, step_size: 7.545207e-04
# time for Adam #234: 0.09s, main loop value (final batch loss): 2.893398e-01, step_size: 7.408768e-04
# time for Adam #235: 0.09s, main loop value (final batch loss): 2.824707e-01, step_size: 7.269952e-04
# time for Adam #236: 0.10s, main loop value (final batch loss): 2.792503e-01, step_size: 7.128896e-04
# time for Adam #237: 0.09s, main loop value (final batch loss): 2.477064e-01, step_size: 6.985739e-04
# time for Adam #238: 0.09s, main loop value (final batch loss): 2.432878e-01, step_size: 6.840623e-04
# time for Adam #239: 0.09s, main loop value (final batch loss): 2.691729e-01, step_size: 6.693690e-04
# time for Adam #240: 0.09s, main loop value (final batch loss): 2.688382e-01, step_size: 6.545085e-04
# time for Adam #241: 0.10s, main loop value (final batch loss): 2.150798e-01, step_size: 6.394956e-04
# time for Adam #242: 0.11s, main loop value (final batch loss): 2.136235e-01, step_size: 6.243449e-04
# time for Adam #243: 0.09s, main loop value (final batch loss): 2.124073e-01, step_size: 6.090716e-04
# time for Adam #244: 0.09s, main loop value (final batch loss): 2.101050e-01, step_size: 5.936907e-04
# time for Adam #245: 0.10s, main loop value (final batch loss): 2.544470e-01, step_size: 5.782172e-04
# time for Adam #246: 0.09s, main loop value (final batch loss): 2.549874e-01, step_size: 5.626666e-04
# time for Adam #247: 0.09s, main loop value (final batch loss): 2.049043e-01, step_size: 5.470542e-04
# time for Adam #248: 0.09s, main loop value (final batch loss): 2.081325e-01, step_size: 5.313953e-04
# time for Adam #249: 0.09s, main loop value (final batch loss): 2.068661e-01, step_size: 5.157054e-04
# time for Adam #250: 0.09s, main loop value (final batch loss): 2.479464e-01, step_size: 5.000000e-04
# time for Adam #251: 0.09s, main loop value (final batch loss): 2.017540e-01, step_size: 4.842946e-04
# time for Adam #252: 0.09s, main loop value (final batch loss): 2.447027e-01, step_size: 4.686047e-04
# time for Adam #253: 0.09s, main loop value (final batch loss): 1.965536e-01, step_size: 4.529458e-04
# time for Adam #254: 0.09s, main loop value (final batch loss): 1.970433e-01, step_size: 4.373334e-04
# time for Adam #255: 0.09s, main loop value (final batch loss): 1.952683e-01, step_size: 4.217828e-04
# time for Adam #256: 0.09s, main loop value (final batch loss): 2.413138e-01, step_size: 4.063093e-04
# time for Adam #257: 0.09s, main loop value (final batch loss): 1.937986e-01, step_size: 3.909284e-04
# time for Adam #258: 0.09s, main loop value (final batch loss): 1.932003e-01, step_size: 3.756551e-04
# time for Adam #259: 0.09s, main loop value (final batch loss): 2.384043e-01, step_size: 3.605044e-04
# time for Adam #260: 0.09s, main loop value (final batch loss): 1.910081e-01, step_size: 3.454915e-04
# time for Adam #261: 0.09s, main loop value (final batch loss): 1.855089e-01, step_size: 3.306310e-04
# time for Adam #262: 0.09s, main loop value (final batch loss): 2.344994e-01, step_size: 3.159377e-04
# time for Adam #263: 0.09s, main loop value (final batch loss): 1.884423e-01, step_size: 3.014261e-04
# time for Adam #264: 0.09s, main loop value (final batch loss): 1.877283e-01, step_size: 2.871104e-04
# time for Adam #265: 0.09s, main loop value (final batch loss): 2.327577e-01, step_size: 2.730048e-04
# time for Adam #266: 0.09s, main loop value (final batch loss): 1.866786e-01, step_size: 2.591232e-04
# time for Adam #267: 0.09s, main loop value (final batch loss): 1.863089e-01, step_size: 2.454793e-04
# time for Adam #268: 0.09s, main loop value (final batch loss): 2.304248e-01, step_size: 2.320866e-04
# time for Adam #269: 0.09s, main loop value (final batch loss): 1.780855e-01, step_size: 2.189583e-04
# time for Adam #270: 0.09s, main loop value (final batch loss): 1.779177e-01, step_size: 2.061074e-04
# time for Adam #271: 0.09s, main loop value (final batch loss): 1.774115e-01, step_size: 1.935465e-04
# time for Adam #272: 0.09s, main loop value (final batch loss): 1.833095e-01, step_size: 1.812880e-04
# time for Adam #273: 0.09s, main loop value (final batch loss): 1.757203e-01, step_size: 1.693441e-04
# time for Adam #274: 0.09s, main loop value (final batch loss): 1.826997e-01, step_size: 1.577264e-04
# time for Adam #275: 0.09s, main loop value (final batch loss): 2.273172e-01, step_size: 1.464466e-04
# time for Adam #276: 0.09s, main loop value (final batch loss): 1.733974e-01, step_size: 1.355157e-04
# time for Adam #277: 0.09s, main loop value (final batch loss): 2.267087e-01, step_size: 1.249445e-04
# time for Adam #278: 0.09s, main loop value (final batch loss): 1.726736e-01, step_size: 1.147434e-04
# time for Adam #279: 0.09s, main loop value (final batch loss): 1.811918e-01, step_size: 1.049225e-04
# time for Adam #280: 0.09s, main loop value (final batch loss): 1.723081e-01, step_size: 9.549150e-05
# time for Adam #281: 0.09s, main loop value (final batch loss): 1.722032e-01, step_size: 8.645971e-05
# time for Adam #282: 0.09s, main loop value (final batch loss): 2.250302e-01, step_size: 7.783604e-05
# time for Adam #283: 0.09s, main loop value (final batch loss): 2.253075e-01, step_size: 6.962899e-05
# time for Adam #284: 0.09s, main loop value (final batch loss): 1.708468e-01, step_size: 6.184666e-05
# time for Adam #285: 0.09s, main loop value (final batch loss): 1.801632e-01, step_size: 5.449674e-05
# time for Adam #286: 0.10s, main loop value (final batch loss): 2.248032e-01, step_size: 4.758647e-05
# time for Adam #287: 0.09s, main loop value (final batch loss): 1.800862e-01, step_size: 4.112269e-05
# time for Adam #288: 0.09s, main loop value (final batch loss): 1.800487e-01, step_size: 3.511176e-05
# time for Adam #289: 0.10s, main loop value (final batch loss): 2.246681e-01, step_size: 2.955962e-05
# time for Adam #290: 0.09s, main loop value (final batch loss): 1.799220e-01, step_size: 2.447174e-05
# time for Adam #291: 0.09s, main loop value (final batch loss): 1.798665e-01, step_size: 1.985316e-05
# time for Adam #292: 0.09s, main loop value (final batch loss): 1.697502e-01, step_size: 1.570842e-05
# time for Adam #293: 0.09s, main loop value (final batch loss): 1.797646e-01, step_size: 1.204162e-05
# time for Adam #294: 0.10s, main loop value (final batch loss): 2.242745e-01, step_size: 8.856375e-06
# time for Adam #295: 0.10s, main loop value (final batch loss): 1.696675e-01, step_size: 6.155830e-06
# time for Adam #296: 0.09s, main loop value (final batch loss): 2.242504e-01, step_size: 3.942649e-06
# time for Adam #297: 0.09s, main loop value (final batch loss): 1.796904e-01, step_size: 2.219018e-06
# time for Adam #298: 0.09s, main loop value (final batch loss): 2.242370e-01, step_size: 9.866358e-07
# time for Adam #299: 0.09s, main loop value (final batch loss): 1.796861e-01, step_size: 2.467198e-07
# time for Adam #300: 0.09s, main loop value (final batch loss): 2.248884e-01, step_size: 1.000000e-03
# time for Adam #301: 0.10s, main loop value (final batch loss): 1.768085e-01, step_size: 1.000000e-03
# time for Adam #302: 0.10s, main loop value (final batch loss): 1.748719e-01, step_size: 1.000000e-03
# time for Adam #303: 0.09s, main loop value (final batch loss): 1.677786e-01, step_size: 1.000000e-03
# time for Adam #304: 0.09s, main loop value (final batch loss): 1.641645e-01, step_size: 1.000000e-03
# time for Adam #305: 0.09s, main loop value (final batch loss): 1.688203e-01, step_size: 1.000000e-03
# time for Adam #306: 0.10s, main loop value (final batch loss): 1.685538e-01, step_size: 1.000000e-03
# time for Adam #307: 0.09s, main loop value (final batch loss): 2.147533e-01, step_size: 1.000000e-03
# time for Adam #308: 0.09s, main loop value (final batch loss): 1.642012e-01, step_size: 1.000000e-03
# time for Adam #309: 0.09s, main loop value (final batch loss): 2.060129e-01, step_size: 1.000000e-03
# time for Adam #310: 0.09s, main loop value (final batch loss): 1.452493e-01, step_size: 1.000000e-03
# time for Adam #311: 0.10s, main loop value (final batch loss): 2.010168e-01, step_size: 1.000000e-03
# time for Adam #312: 0.10s, main loop value (final batch loss): 1.408295e-01, step_size: 1.000000e-03
# time for Adam #313: 0.10s, main loop value (final batch loss): 2.004197e-01, step_size: 1.000000e-03
# time for Adam #314: 0.10s, main loop value (final batch loss): 2.055272e-01, step_size: 1.000000e-03
# time for Adam #315: 0.10s, main loop value (final batch loss): 2.021253e-01, step_size: 1.000000e-03
# time for Adam #316: 0.10s, main loop value (final batch loss): 2.016004e-01, step_size: 1.000000e-03
# time for Adam #317: 0.09s, main loop value (final batch loss): 1.323020e-01, step_size: 1.000000e-03
# time for Adam #318: 0.09s, main loop value (final batch loss): 1.350814e-01, step_size: 1.000000e-03
# time for Adam #319: 0.09s, main loop value (final batch loss): 1.470975e-01, step_size: 1.000000e-03
# time for Adam #320: 0.10s, main loop value (final batch loss): 1.926186e-01, step_size: 1.000000e-03
# time for Adam #321: 0.09s, main loop value (final batch loss): 2.199366e-01, step_size: 1.000000e-03
# time for Adam #322: 0.09s, main loop value (final batch loss): 1.277759e-01, step_size: 1.000000e-03
# time for Adam #323: 0.09s, main loop value (final batch loss): 2.002556e-01, step_size: 1.000000e-03
# time for Adam #324: 0.09s, main loop value (final batch loss): 1.238682e-01, step_size: 1.000000e-03
# time for Adam #325: 0.09s, main loop value (final batch loss): 1.385860e-01, step_size: 1.000000e-03
# time for Adam #326: 0.09s, main loop value (final batch loss): 1.262471e-01, step_size: 1.000000e-03
# time for Adam #327: 0.09s, main loop value (final batch loss): 1.500559e-01, step_size: 1.000000e-03
# time for Adam #328: 0.09s, main loop value (final batch loss): 1.609423e-01, step_size: 1.000000e-03
# time for Adam #329: 0.09s, main loop value (final batch loss): 2.071743e-01, step_size: 1.000000e-03
# time for Adam #330: 0.09s, main loop value (final batch loss): 1.282487e-01, step_size: 1.000000e-03
# time for Adam #331: 0.09s, main loop value (final batch loss): 1.867405e-01, step_size: 1.000000e-03
# time for Adam #332: 0.09s, main loop value (final batch loss): 1.988733e-01, step_size: 1.000000e-03
# time for Adam #333: 0.09s, main loop value (final batch loss): 2.946681e-01, step_size: 1.000000e-03
# time for Adam #334: 0.09s, main loop value (final batch loss): 2.264689e-01, step_size: 1.000000e-03
# time for Adam #335: 0.09s, main loop value (final batch loss): 3.772594e-01, step_size: 1.000000e-03
# time for Adam #336: 0.09s, main loop value (final batch loss): 4.331309e-01, step_size: 1.000000e-03
# time for Adam #337: 0.09s, main loop value (final batch loss): 4.280634e-01, step_size: 1.000000e-03
# time for Adam #338: 0.09s, main loop value (final batch loss): 2.689305e-01, step_size: 1.000000e-03
# time for Adam #339: 0.09s, main loop value (final batch loss): 1.676508e-01, step_size: 1.000000e-03
# time for Adam #340: 0.09s, main loop value (final batch loss): 2.150673e-01, step_size: 1.000000e-03
# time for Adam #341: 0.09s, main loop value (final batch loss): 1.338050e-01, step_size: 1.000000e-03
# time for Adam #342: 0.09s, main loop value (final batch loss): 2.087385e-01, step_size: 1.000000e-03
# time for Adam #343: 0.09s, main loop value (final batch loss): 1.777911e-01, step_size: 1.000000e-03
# time for Adam #344: 0.09s, main loop value (final batch loss): 1.425997e-01, step_size: 1.000000e-03
# time for Adam #345: 0.10s, main loop value (final batch loss): 1.840280e-01, step_size: 1.000000e-03
# time for Adam #346: 0.09s, main loop value (final batch loss): 1.954162e-01, step_size: 1.000000e-03
# time for Adam #347: 0.09s, main loop value (final batch loss): 1.561063e-01, step_size: 1.000000e-03
# time for Adam #348: 0.09s, main loop value (final batch loss): 1.636596e-01, step_size: 1.000000e-03
# time for Adam #349: 0.09s, main loop value (final batch loss): 1.827475e-01, step_size: 1.000000e-03
# time for Adam #350: 0.09s, main loop value (final batch loss): 1.995212e-01, step_size: 1.000000e-03
# time for Adam #351: 0.09s, main loop value (final batch loss): 1.451494e-01, step_size: 1.000000e-03
# time for Adam #352: 0.09s, main loop value (final batch loss): 1.645558e-01, step_size: 1.000000e-03
# time for Adam #353: 0.09s, main loop value (final batch loss): 1.166624e-01, step_size: 1.000000e-03
# time for Adam #354: 0.09s, main loop value (final batch loss): 1.187918e-01, step_size: 1.000000e-03
# time for Adam #355: 0.09s, main loop value (final batch loss): 1.697705e-01, step_size: 1.000000e-03
# time for Adam #356: 0.09s, main loop value (final batch loss): 1.313277e-01, step_size: 1.000000e-03
# time for Adam #357: 0.10s, main loop value (final batch loss): 1.696724e-01, step_size: 1.000000e-03
# time for Adam #358: 0.09s, main loop value (final batch loss): 1.698613e-01, step_size: 1.000000e-03
# time for Adam #359: 0.09s, main loop value (final batch loss): 1.348422e-01, step_size: 1.000000e-03
# time for Adam #360: 0.09s, main loop value (final batch loss): 2.183800e-01, step_size: 1.000000e-03
# time for Adam #361: 0.09s, main loop value (final batch loss): 1.030796e-01, step_size: 1.000000e-03
# time for Adam #362: 0.09s, main loop value (final batch loss): 2.061458e-01, step_size: 1.000000e-03
# time for Adam #363: 0.09s, main loop value (final batch loss): 1.378243e-01, step_size: 1.000000e-03
# time for Adam #364: 0.09s, main loop value (final batch loss): 1.843924e-01, step_size: 1.000000e-03
# time for Adam #365: 0.09s, main loop value (final batch loss): 1.446370e-01, step_size: 1.000000e-03
# time for Adam #366: 0.09s, main loop value (final batch loss): 2.695925e-01, step_size: 1.000000e-03
# time for Adam #367: 0.09s, main loop value (final batch loss): 1.814575e-01, step_size: 1.000000e-03
# time for Adam #368: 0.09s, main loop value (final batch loss): 1.460186e-01, step_size: 1.000000e-03
# time for Adam #369: 0.09s, main loop value (final batch loss): 1.849092e-01, step_size: 1.000000e-03
# time for Adam #370: 0.09s, main loop value (final batch loss): 2.841752e-01, step_size: 1.000000e-03
# time for Adam #371: 0.09s, main loop value (final batch loss): 2.478317e-01, step_size: 1.000000e-03
# time for Adam #372: 0.09s, main loop value (final batch loss): 1.308132e-01, step_size: 1.000000e-03
# time for Adam #373: 0.09s, main loop value (final batch loss): 1.136375e-01, step_size: 1.000000e-03
# time for Adam #374: 0.09s, main loop value (final batch loss): 1.231918e-01, step_size: 1.000000e-03
# time for Adam #375: 0.09s, main loop value (final batch loss): 2.254396e-01, step_size: 1.000000e-03
# time for Adam #376: 0.09s, main loop value (final batch loss): 2.095261e-01, step_size: 1.000000e-03
# time for Adam #377: 0.09s, main loop value (final batch loss): 2.688795e-01, step_size: 1.000000e-03
# time for Adam #378: 0.10s, main loop value (final batch loss): 1.398380e-01, step_size: 1.000000e-03
# time for Adam #379: 0.10s, main loop value (final batch loss): 1.066708e-01, step_size: 1.000000e-03
# time for Adam #380: 0.09s, main loop value (final batch loss): 1.319032e-01, step_size: 1.000000e-03
# time for Adam #381: 0.09s, main loop value (final batch loss): 1.559416e-01, step_size: 1.000000e-03
# time for Adam #382: 0.09s, main loop value (final batch loss): 8.615087e-02, step_size: 1.000000e-03
# time for Adam #383: 0.09s, main loop value (final batch loss): 1.037753e-01, step_size: 1.000000e-03
# time for Adam #384: 0.09s, main loop value (final batch loss): 1.684062e-01, step_size: 1.000000e-03
# time for Adam #385: 0.09s, main loop value (final batch loss): 1.014537e-01, step_size: 1.000000e-03
# time for Adam #386: 0.09s, main loop value (final batch loss): 1.359661e-01, step_size: 1.000000e-03
# time for Adam #387: 0.09s, main loop value (final batch loss): 1.689556e-01, step_size: 1.000000e-03
# time for Adam #388: 0.09s, main loop value (final batch loss): 1.036796e-01, step_size: 1.000000e-03
# time for Adam #389: 0.10s, main loop value (final batch loss): 1.322943e-01, step_size: 1.000000e-03
# time for Adam #390: 0.09s, main loop value (final batch loss): 1.816146e-01, step_size: 1.000000e-03
# time for Adam #391: 0.09s, main loop value (final batch loss): 1.959619e-01, step_size: 1.000000e-03
# time for Adam #392: 0.09s, main loop value (final batch loss): 7.256430e-02, step_size: 1.000000e-03
# time for Adam #393: 0.09s, main loop value (final batch loss): 1.123307e-01, step_size: 1.000000e-03
# time for Adam #394: 0.09s, main loop value (final batch loss): 1.026784e-01, step_size: 1.000000e-03
# time for Adam #395: 0.09s, main loop value (final batch loss): 1.343646e-01, step_size: 1.000000e-03
# time for Adam #396: 0.09s, main loop value (final batch loss): 1.557217e-01, step_size: 1.000000e-03
# time for Adam #397: 0.09s, main loop value (final batch loss): 1.724749e-01, step_size: 1.000000e-03
# time for Adam #398: 0.09s, main loop value (final batch loss): 1.051174e-01, step_size: 1.000000e-03
# time for Adam #399: 0.09s, main loop value (final batch loss): 1.379246e-01, step_size: 1.000000e-03
# Rank 0 finished training!

# %% [markdown]
# ### Predict $\Sigma(i\omega)$ with MBGF-Net
# using the gnn_orch object, take an unseen molecule from a chkfile (ethane) and compute its self-energy in the SAIAO basis.

# %%
import joblib
gnn_orch = joblib.load('test_gnn_orchestrator.joblib')

# predict sigma(iw) in the SAIAO basis froma chkfile not seen in the training dataset
example_chkfile = 'test_chk/ethane.chk'
sigma_ml = gnn_orch.predict_full_sigma(example_chkfile)
# Out:
# /root/capsule/code/mlgf/mlgf/lib/pes.py:10: UserWarning: PES fitting is not available: No module named 'cvxpy'
#   warnings.warn(f"PES fitting is not available: {e}")

# %% [markdown]
# ### Post process the predicted $\textit{GW}$ self-energy to get density matrix, qpe, and photoemission spectrum

# %%
# the pdset attribute contains the Moldatum object that was mounted for an MBGF-Net prediction
mlf = gnn_orch.pdset[0]

# extract the SAIAO to MO rotation for sigma(iw)
C_saiao_mo = mlf['C_saiao_mo']

# rotate sigma(iw) to MO basis
from mlgf.lib.helpers import sigma_lo_mo
sigma_ml_mo = sigma_lo_mo(sigma_ml, C_saiao_mo) 

# extract the properties from MBGF and self-energy, takes sigma in the MO basis, can be machine learned sigma or true self-energy
from mlgf.workflow.get_ml_info import get_properties
import numpy as np
eta = 0.01 # band broadening for DOS
freqs = np.linspace(-1, 1, 201) # real frequency points on which to evaluate the DOS
properties = 'dqm' # a short string denoting which properties to compute from sigma: d - dos, q - qpe, m - density matrix

properties_ml = get_properties(sigma_ml_mo, mlf, freqs, eta, properties = properties)
properties_true = get_properties(mlf['sigmaI'], mlf, freqs, eta, properties = properties)

# %% [markdown]
# ### Compare the property predictions derived to from MLGF with the true reference(s)
# Ethane should have a poor LUMO prediction, because the training data lacks a C-C single bond.

# %%
au_to_ev = 27.21
nocc = mlf['nocc']

homo_error = properties_ml['qpe'][nocc-1] - properties_true['qpe'][nocc-1]
print(f'HOMO Error (eV): {homo_error*au_to_ev:0.4f}') 

lumo_error = properties_ml['qpe'][nocc] - properties_true['qpe'][nocc]
print(f'LUMO Error (eV): {lumo_error*au_to_ev:0.4f}') 

dm_mae = np.mean(np.abs(properties_ml['dm'] - properties_true['dm']))
print(f'Density matrix MAE: {dm_mae:0.4f}') 

# dipoles and quadrupoles, note predicted dm is in MO basis
from mlgf.lib.dm_helper import dm_mo_to_ao, get_dipole, scalar_quadrupole
from pyscf import dft, lib
mol = lib.chkfile.load_mol(example_chkfile)
rks = dft.RKS(mol)
rks.xc = mlf['xc'].decode('utf-8')
scf_data = lib.chkfile.load(example_chkfile, 'scf')
rks.__dict__.update(scf_data)
dipole_ml = get_dipole(rks, dm_mo_to_ao(properties_ml['dm'], scf_data['mo_coeff']))
dipole_true = get_dipole(rks, dm_mo_to_ao(properties_true['dm'], scf_data['mo_coeff']))

quadrupole_ml = scalar_quadrupole(mol, dm_mo_to_ao(properties_ml['dm'], scf_data['mo_coeff']))
quadrupole_true = scalar_quadrupole(mol, dm_mo_to_ao(properties_true['dm'], scf_data['mo_coeff']))

print(f'Dipole error (Debye): {(dipole_ml-dipole_true):0.4f}') 
print(f'Quadrupole error (Debye⋅Å): {(quadrupole_ml-quadrupole_true):0.4f}')
# Out:
# HOMO Error (eV): 0.0977
# LUMO Error (eV): 0.5847
# Density matrix MAE: 0.0005
# Dipole error (Debye): 0.2615
# Quadrupole error (Debye⋅Å): -0.1182
